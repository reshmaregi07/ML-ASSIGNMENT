# %% [markdown]
# #### https://github.com/reshmaregi07/ML-ASSIGNMENT

# %% [markdown]
# # Assessment 1

# %% [markdown]
# ### Task 1: Search String with Website info

# %% [markdown]
# ### Task 2: Top 20 Search Results

# %% [markdown]
# ![WhatsApp%20Image%202021-03-02%20at%207.48.46%20PM.jpeg](attachment:WhatsApp%20Image%202021-03-02%20at%207.48.46%20PM.jpeg)

# %% [markdown]
# ![ss1.png](attachment:ss1.png)

# %% [markdown]
# ![WhatsApp%20Image%202021-03-02%20at%207.37.41%20PM.jpeg](attachment:WhatsApp%20Image%202021-03-02%20at%207.37.41%20PM.jpeg)

# %% [markdown]
# ![WhatsApp%20Image%202021-03-02%20at%207.36.54%20PM.jpeg](attachment:WhatsApp%20Image%202021-03-02%20at%207.36.54%20PM.jpeg)

# %% [markdown]
# ![Screenshot%20%28262%29.png](attachment:Screenshot%20%28262%29.png)

# %% [markdown]
# ![WhatsApp%20Image%202021-03-02%20at%207.36.25%20PM.jpeg](attachment:WhatsApp%20Image%202021-03-02%20at%207.36.25%20PM.jpeg)

# %% [markdown]
# ![Screenshot%20%28261%29.png](attachment:Screenshot%20%28261%29.png)

# %% [markdown]
# ![WhatsApp%20Image%202021-03-02%20at%207.37.04%20PM.jpeg](attachment:WhatsApp%20Image%202021-03-02%20at%207.37.04%20PM.jpeg)

# %% [markdown]
# # Task 3: Identify the features

# %% [markdown]
# # Task 4: Organize them into a Table

# %% [markdown]
# ![WhatsApp%20Image%202021-03-02%20at%2010.28.15%20PM.jpeg](attachment:WhatsApp%20Image%202021-03-02%20at%2010.28.15%20PM.jpeg)

# %%
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# %%
# Import the numpy and pandas packages

import numpy as np
import pandas as pd

# %%
# Read the csv file using 'read_csv'
df = pd.read_excel(r'C:\Users\reshm\Downloads\Dataset.xlsx')
df
# Out:
#                       Name    Location     Price  Square_area  Floor  \
# 0  fortune nest appartment      gantok  20000000         1200      1
# 1                     Null      Shimla   6500000         1650      2
# 2         Studio Apartment    Nainital   2500000          463      1
# 3         Shankara Estates        Ooty  30000000         3950      2
# 4              Zacs Valley  Kodaikanal   5500000         4000      0
# 5              elite infra      shimla   6500000         1390      2
# 6            sunrise place      shimla   8500000         1700      1
# 7  Owner Residential House  Kodaikanal  20000000         2500      1
# 8     Annandale Golf Drive      shimla   5000000         2003      0
# 9         Naline apartment   Shilllong  10000000         3000      1
#
#    No. of Rooms Parking          View
# 0             2       y            NaN
# 1             3       y            NaN
# 2             1       y         Garden
# 3             3       y  Garden, Road
# ...

# %% [markdown]
# # Task 5: Identify 5 suitable Feature Engineering Tasks (Give reasons where ever possible)

# %% [markdown]
# #### 1) Mapping the data

# %%
# Converting y to :1 and n to :0 for better understanding


df['Parking']= df['Parking'].map({'y':1,'n':0})

# %%
#Checking the atribute
df.head()
# Out:
#                       Name    Location     Price  Square_area  Floor  \
# 0  fortune nest appartment      gantok  20000000         1200      1
# 1                     Null      Shimla   6500000         1650      2
# 2         Studio Apartment    Nainital   2500000          463      1
# 3         Shankara Estates        Ooty  30000000         3950      2
# 4              Zacs Valley  Kodaikanal   5500000         4000      0
#
#    No. of Rooms  Parking          View
# 0             2        1            NaN
# 1             3        1            NaN
# 2             1        1         Garden
# 3             3        1  Garden, Road
# 4             2        1         Garden

# %% [markdown]
# #### 2) Data tyes

# %% [raw]
# df.dtypes

# %%
# Get a summary of the dataframe using 'describe()'
df.describe()
# Out:
#               Price  Square_area      Floor  No. of Rooms    Parking
# count  1.000000e+01    10.000000  10.000000     10.000000  10.000000
# mean   1.145000e+07  2185.600000   1.100000      2.400000   0.600000
# std    8.864567e+06  1168.807769   0.737865      1.349897   0.516398
# min    2.500000e+06   463.000000   0.000000      1.000000   0.000000
# 25%    5.750000e+06  1455.000000   1.000000      1.250000   0.000000
# 50%    7.500000e+06  1851.500000   1.000000      2.000000   1.000000
# 75%    1.750000e+07  2875.000000   1.750000      3.000000   1.000000
# max    3.000000e+07  4000.000000   2.000000      5.000000   1.000000

# %% [markdown]
# #### Information about number of rows and columns

# %%
# Data shape
#Information about number of rows and columns
df.shape
# Out:
# (10, 8)

# %%
# Check the column-wise info of the dataframe

df.info
# Out:
# <bound method DataFrame.info of                       Name    Location     Price  Square_area  Floor  \
# 0  fortune nest appartment      gantok  20000000         1200      1
# 1                     Null      Shimla   6500000         1650      2
# 2         Studio Apartment    Nainital   2500000          463      1
# 3         Shankara Estates        Ooty  30000000         3950      2
# 4              Zacs Valley  Kodaikanal   5500000         4000      0
# 5              elite infra      shimla   6500000         1390      2
# 6            sunrise place      shimla   8500000         1700      1
# 7  Owner Residential House  Kodaikanal  20000000         2500      1
# 8     Annandale Golf Drive      shimla   5000000         2003      0
# 9         Naline apartment   Shilllong  10000000         3000      1
#
#    No. of Rooms  Parking          View
# 0             2        1            NaN
# 1             3        1            NaN
# 2             1        1         Garden
# ...

# %% [markdown]
# #### 3) Type casting of some attributes

# %%
#Converting No. of Rooms from float to integer
df['No. of Rooms']=df['No. of Rooms'].astype(int)

# %%
#Checking the data type of the No. of Rooms
df['No. of Rooms'].dtype
# Out:
# dtype('int32')

# %%
#Typecasting
df['Floor'] = df['Floor'].astype(int)
df['Floor'].dtype
# Out:
# dtype('int32')

# %% [markdown]
# #### 4) Graphical Visualization of realtion between two attributes

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
##Typecasting
df['Square_area'] = df['Square_area'].astype(int)

# %% [markdown]
# #### Plotting  scatter graph betweeen 'Price' and 'Square_area'

# %%
sns.factorplot(x = "Square_area", y = 'Price', data = df)

# %% [markdown]
# #### 5)  Plotting  bar graph betweeen 'Place' and 'price'

# %%
groupedby_places = df.groupby('Location')[['Price']].mean()
print(groupedby_places.sort_values(by = ['Price']))
plt.figure(figsize=(9,6))
plt.bar(x=df['Location'],height=df['Price'])
plt.xticks(rotation=45)
# Out:
#                    Price
# Location
# Nainital    2.500000e+06
# Shimla      6.500000e+06
# shimla      6.666667e+06
# Shilllong   1.000000e+07
# Kodaikanal  1.275000e+07
# gantok      2.000000e+07
# Ooty        3.000000e+07
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# # Vedio Link

# %% [markdown]
# https://screenrec.com/share/gCDNPX9z0F
